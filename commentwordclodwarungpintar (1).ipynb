# %%
import pandas as pd
import numpy as np

url = 'https://raw.githubusercontent.com/qaidin/dataset_warungpintar_ig/master/dataset_z3MeuQvK2LEhiXdcr.csv'
df = pd.read_csv(url)
df.head()
# Out:
#                                         firstComment  ...                                      url
# 0  #SobatWarung pasti tau dong 17 Agustus itu gak...  ...  https://www.instagram.com/p/B1Ql60LAWBX
# 1  Selamat Hari Kemerdekaan Indonesia yang ke-74!...  ...  https://www.instagram.com/p/B1QZHXsgPLF
# 2  #SobatWarung pernah gak sih kalian punya suatu...  ...  https://www.instagram.com/p/B1Nr0gzAQPn
# 3  Gini nih jadinya kalau Juragan Warung dan AnWa...  ...  https://www.instagram.com/p/B1LuZEbgyYh
# 4  Menjalankan perintahnya karena yakin akan menc...  ...  https://www.instagram.com/p/B1BhKwzAopd
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
# firstComment     200 non-null object
# imageUrl         200 non-null object
# likesCount       200 non-null int64
# locationName     0 non-null float64
# ownerUsername    200 non-null object
# timestamp        200 non-null object
# url              200 non-null object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 11.0+ KB

# %%
df1 = pd.DataFrame(df['firstComment'])
df1.head()
# Out:
#                                         firstComment
# 0  #SobatWarung pasti tau dong 17 Agustus itu gak...
# 1  Selamat Hari Kemerdekaan Indonesia yang ke-74!...
# 2  #SobatWarung pernah gak sih kalian punya suatu...
# 3  Gini nih jadinya kalau Juragan Warung dan AnWa...
# 4  Menjalankan perintahnya karena yakin akan menc...

# %%
df1.rename(columns={'firstComment':'text'},inplace = True)
df1.tail()
# Out:
#                                                   text
# 195  Kalau Sobat Warung ada pertanyaan seputar prog...
# 196  Selain anak SMA, MaWar juga sering ketemu sama...
# 197  Sobat Warung yang punya akun Twitter sekarang ...
# 198  Setelah hampir seminggu penuh kerja keras, akh...
# 199  Sobat Warung bisa menemukan perbedaannya nggak...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 1 columns):
# text    200 non-null object
# dtypes: object(1)
# memory usage: 1.6+ KB

# %%
 df2=df1['text'].str.cat(sep=' ')
 df2
# Out:
# '#SobatWarung pasti tau dong 17 Agustus itu gak akan bisa terwujud tanpa perjuangan para pahlawan? Tapi, tentunya mereka gak sendiri!\n\nContoh, dulu, Bung Karno bermimpi untuk bisa wujudin kemerdekaan buat Indonesia. Dalam perjalanannya menuju mimpi itu, ia gak sendirian. Ada Bung Hatta yang selalu mendukung dan berjuang bareng beliau.\n\nNah, itulah Sobat Warung, sehebat-hebatnya pahlawan, ia selalu punya teman untuk terus berjuang bareng. Kalau Sobat Warung siapa nih #Teman17an nya? Selamat Hari Kemerdekaan Indonesia yang ke-74!\n\n#SobatWarung udah ikut lomba apa aja nih? Ngomong-ngomong soal 17 Agustus, ternyata ini arti #Teman17an bagi beberapa Sobat Warung.\n\nKamu punya arti #Teman17an yang lain? Komen ya! #SobatWarung pernah gak sih kalian punya suatu mimpi terus ngerasa kesulitan buat ngewujudinnya sendiri dan akhirnya ketemu teman yang tepat untuk ngejar bareng mimpi itu?\n\nKemarin kita baru aja nanya apa arti #Teman17an menurut kamu, nah sekarang di Episode 9 Obrolan Warung, @bezhariehadinegoro, CEO Warung Pintar, dan @yudaaritonang, Project Manager Warung Pintar, akan nyeritain apa arti Teman 17an bagi mereka!\n\u2063\nDengerin #ObrolanWarung di Spotify dan Apple Podcast 😊 Gini nih jadinya kalau Juragan Warung dan AnWar (Anak Warung: staff warung pintar) kerja bareng dalam satu tujuan!\n\nIni mereka lagi ngehias warung bareng untuk lomba 17an #HiasWarungPintar.\n\nKalau Juragan Warung lain pada gimana ngehias warungnya? Tunjukkin dong ke kita lewat posting di media sosial pakai Twibbon #Teman17an (link di bio) dan tag kita ya! Biar kita saling berbagi kebahagiaan bareng 😊 Menjalankan perintahnya karena yakin akan mencapai satu tujuan. \u2063\n\u2063\nMeyakini ada pahala di setiap helai bulunya, dan meyakini ada cinta di setiap pengorbanan yang dilakukan.\u2063\n\u2063\nSelamat Hari Raya IdulAdha 1440 H. #PintarnyaWarungPintar bukan hanya sekedar warung dengan tivi, tapi tentang bagaimana perluas koneksi dan berinovasi.\n\nIni #TipsJuraganPintar Ridwansyah di WP Makmur IV 1. Kalau tips versi Juragan, gimana? Share dong di kolom komen. Siapa yang suka bakmi Djawa? Kalau tiba-tiba lagi kangen kampung halaman, atau merasa mulai susah mencari tempat yang jual Bakmi Djawa, cobain deh mampir di warungnya Mbak Lies (Sulis Mariyanti). \u2063\n\u2063\nAda menu lainnya juga seperti ayam goreng Kalasan, ayam gombal, soto bening, dan aneka nasi goreng!\u2063\n\u2063\nKlo baca spanduknya “Coba Dulu Aja!”, yuk cobain bareng-bareng ke sini!\u2063\n\u2063\n(Lokasi : Jalan Raya Gas Alam, No.64, 004/004, Kelurahan Sukatani, Kecamatan Tapos, Kota Depok)\u2063\n\u2063\n#SEHARIDIWARPIN Kenalan sama AnWar lagi yuk!\u2063\nNita adalah AnWar yang tiap hari harus berkomunikasi dengan calon Juragan yang berbeda, baik itu melalui telepon atau hanya chatting aja.\u2063\n\u2063\nMulai dari menganalisis data, sampai memvalidasi calon Juragan yang sesuai kriteria. Calon Juragan yang beneran mau usaha, bukan cuma aji mumpung doang, sehingga keputusannya valid jatuh kepada Juragan yang mau berkembang dan tumbuh bersama Warung Pintar.\u2063\n\u2063\n#KenalanPintar Bukan soal sekedar warung pake Wifi, tapi tentang gimana caranya Juragan dan juga customer bisa memperluas koneksi, berinovasi, dan memanfaatkan fasilitas untuk berkembang.\u2063\n\u2063\nSeperti di video ini, #PintarnyaWarungPintar mendekatkan yang jauh, mengobati rasa rindu Dina ke bapaknya. Menurut kalian, salah gak sih kalo apa yang kita pelajari selama ini di kuliah justru kita tinggalin dan nekunin bidang yang jauh berbeda?\u2063\n\u2063\nHal ini kejadian sama Azka, Acquisition Manager Warung Pintar dari Tribe Retail yang dulunya ngambil kuliah Hukum sampe S2. Nah.. Mendingan langsung aja kita simak alasannya dan bagaimana Azka bisa bertahan di dunia yang jauh berbeda dari yang dia pelajari selama kuliah.\u2063\n\u2063\nDengerin #ObrolanWarung di Spotify (swipe up link di highlight stories), Soundcloud atau Apple Podcast sekarang juga! Nah.. Ini dia nih yang menjadi gerbang utamany ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from textblob import TextBlob

# %%
#removing numbers
def remove_num(df2):
    df2 = ''.join([i for i in df2 if not i.isdigit()])
    return df2

#executing function
df2 = np.vectorize(remove_num)(df2)

# %%
from string import punctuation
def remove_punct(df2):
    df2 = ' '.join(word.strip(punctuation) for word in df2.split() if word.strip(punctuation))
    return df2

#executing function
df2 = np.vectorize(remove_punct)(df2)

# %%
def remove_u(df2):
    df2 = df2.replace('_','')
    df2 = df2.replace('?','')
    df2 = df2.replace('•','')
    df2 = df2.replace("@",'')
    df2 = df2.replace('▯','')
    df2 = df2.replace("'",'')
    df2 = df2.replace(",",'')
    df2 = df2.replace("#",'')
    df2 = df2.replace("/",'')
    df2 = df2.replace("|",'')
    df2 = df2.replace("|",'')
    df2 = df2.replace("||",'')                  
    return df2

#executing function
df2 = np.vectorize(remove_u)(df2)

# %%
def remove_extra_space(df2):
    word_list = df2.split()
    df22 = ' '.join(word_list)
    return df2

#executing function
df2 = np.vectorize(remove_extra_space)(df2)

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan', 'oh', 'ok', 'seharusnya', 'sebetulnya', 'setiap', 'setidaknya', 'sesuatu', 'pasti', 'saja', 'toh', 'ya', 'walau', 'tolong', 'tentu', 'amat', 'apalagi', 'bagaimanapun']

# %%
# import StopWordRemoverFactory class
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()
 
# Kalimat
stop = stopword.remove(df2)
print(stop)
# Out:
# SobatWarung tau dong Agustus gak terwujud perjuangan pahlawan Tapi tentunya gak sendiri Contoh dulu Bung Karno bermimpi wujudin kemerdekaan buat Indonesia Dalam perjalanannya menuju mimpi gak sendirian Ada Bung Hatta selalu mendukung berjuang bareng beliau Nah Sobat Warung sehebat-hebatnya pahlawan ia selalu punya teman terus berjuang bareng Kalau Sobat Warung siapa nih Temanan nya Selamat Hari Kemerdekaan Indonesia SobatWarung udah ikut lomba apa aja nih Ngomong-ngomong soal Agustus ternyata arti Temanan beberapa Sobat Warung Kamu punya arti Temanan Komen SobatWarung pernah gak sih kalian punya suatu mimpi terus ngerasa kesulitan buat ngewujudinnya sendiri akhirnya ketemu teman tepat ngejar bareng mimpi Kemarin baru aja nanya apa arti Temanan kamu nah sekarang Episode Obrolan Warung bezhariehadinegoro CEO Warung Pintar yudaaritonang Project Manager Warung Pintar nyeritain apa arti Teman an ⁣ Dengerin ObrolanWarung Spotify Apple Podcast 😊 Gini nih jadinya kalau Juragan Warung AnWar Anak Warung staff warung pintar kerja bareng satu tujuan Ini ngehias warung bareng lomba an HiasWarungPintar Kalau Juragan Warung gimana ngehias warungnya Tunjukkin dong lewat posting media sosial pakai Twibbon Temanan link bio tag Biar saling berbagi kebahagiaan bareng 😊 Menjalankan perintahnya yakin mencapai satu tujuan ⁣ ⁣ Meyakini pahala helai bulunya meyakini cinta pengorbanan dilakukan.⁣ ⁣ Selamat Hari Raya IdulAdha H PintarnyaWarungPintar bukan sekedar warung tivi bagaimana perluas koneksi berinovasi Ini TipsJuraganPintar Ridwansyah WP Makmur IV Kalau tips versi Juragan gimana Share dong kolom komen Siapa suka bakmi Djawa Kalau tiba-tiba kangen kampung halaman merasa mulai susah mencari tempat jual Bakmi Djawa cobain deh mampir warungnya Mbak Lies Sulis Mariyanti ⁣ ⁣ Ada menu lainnya ayam goreng Kalasan ayam gombal soto bening aneka nasi goreng!⁣ ⁣ Klo baca spanduknya “Coba Dulu Aja!” yuk cobain bareng-bareng sini!⁣ ⁣ Lokasi Jalan Raya Gas Alam No Kelurahan Sukatani Kecamatan Tapos Kota Depok)⁣ ⁣ SEHARIDIWARPIN Kenalan sama AnWar yuk!⁣ Nita AnWar tiap hari berkomunikasi calon Juragan berbeda baik melalui telepon chatting aja.⁣ ⁣ Mulai menganalisis data memvalidasi calon Juragan sesuai kriteria Calon Juragan beneran mau usaha bukan cuma aji mumpung doang keputusannya valid jatuh Juragan mau berkembang tumbuh bersama Warung Pintar.⁣ ⁣ KenalanPintar Bukan soal sekedar warung pake Wifi gimana caranya Juragan customer memperluas koneksi berinovasi memanfaatkan fasilitas berkembang.⁣ ⁣ Seperti video PintarnyaWarungPintar mendekatkan jauh mengobati rasa rindu Dina bapaknya Menurut kalian salah gak sih kalo apa pelajari selama kuliah justru tinggalin nekunin bidang jauh berbeda⁣ ⁣ Hal kejadian sama Azka Acquisition Manager Warung Pintar Tribe Retail dulunya ngambil kuliah Hukum sampe S Nah Mendingan langsung aja simak alasannya bagaimana Azka bertahan dunia jauh berbeda pelajari selama kuliah.⁣ ⁣ Dengerin ObrolanWarung Spotify swipe up link highlight stories Soundcloud Apple Podcast sekarang Nah Ini nih menjadi gerbang utamanya Warung Pintar klo ga Mba Laras Juragan bingung mau nanya mengadu mana!⁣ ⁣ Tugas doi mulai ngasih tau gambaran umumnya Warung Pintar calon Juragan membantu menyelesaikan problem-problem Juragan mulai komplain pertanyaan seputar Warung Pintar teknis-teknis.⁣ ⁣ Ada mau nanya sama mba Laras Langsung aja hubungi whatsapptelepon aktif hari Senin-Jumat hari libur jam ⁣ ⁣ KenalanPintar Bantuin sih bantuin gak gitu kali bang~⁣⁣ ⁣⁣ TipsJuraganPintar pintar-pintar manfaatin kesempatan jangan males cari rezeki Asal beli mah sampe subuh diladenin sama Juragan!⁣⁣ ⁣⁣ Karena PintarnyaWarungPintar bukan seberapa banyak teknologi disematkan seberapa besar semangat perubahan kerjakan membakar semangat Juragan terus berinovasi Ciyaaaa Padahal mamamia sama insomnia kan jauh Juragan Namanya kelakuan Sobat Warung kadang lucu kadang ngeselin malah kadang bikin kangen Juragan Sobat Warung punya kejadian lebih lucu gak Ceritain dong NgupingJuragan Nah  ...

# %%
import numpy as np
import pandas as pd
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

#--------------------------------------------------------------------------------------

wordcloud = WordCloud().generate(stop)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wine_mask = np.array(Image.open("/content/wapin.png"))
wine_mask
# Out:
# array([[[ 35,  31,  32, 255],
#         [ 35,  31,  32, 255],
#         [ 35,  31,  32, 255],
#         ...,
#         [ 35,  31,  32, 255],
#         [ 35,  31,  32, 255],
#         [ 35,  31,  32, 255]],
#
#        [[ 35,  31,  32, 255],
#         [247, 200,  46, 255],
#         [247, 200,  46, 255],
#         ...,
#         [247, 200,  46, 255],
#         [247, 200,  46, 255],
#         [ 35,  31,  32, 255]],
#
#        [[ 35,  31,  32, 255],
#         [247, 200,  46, 255],
#         [247, 200,  46, 255],
#         ...,
#         [247, 200,  46, 255],
#         [247, 200,  46, 255],
#         [ 35,  31,  32, 255]],
#
#        ...,
#
#        [[ 35,  31,  32, 255],
#         [247, 200,  46, 255],
#         [247, 200,  46, 255],
#         ...,
#         [247, 200,  46, 255],
#         [247, 200,  46, 255],
#         [ 35,  31,  32, 255]],
#
#        [[ 35,  31,  32, 255],
#         [247, 200,  46, 255],
#         [247, 200,  46, 255],
#         ...,
#         [247, 200,  46, 255],
#         [247, 200,  46, 255],
#         [ 35,  31,  32, 255]],
#
#        [[ 35,  31,  32, 255],
#         [ 35,  31,  32, 255],
#         [ 35,  31,  32, 255],
#         ...,
#         [ 35,  31,  32, 255],
#         [ 35,  31,  32, 255],
#         [ 35,  31,  32, 255]]], dtype=uint8)

# %%
def transform_format(val):
    if val == 0:
        return 255
    else:
        return val

# %%
transformed_wine_mask = np.ndarray((wine_mask.shape[0],wine_mask.shape[1]), np.int32)
transformed_wine_mask
# Out:
# array([[-14672093, -14672093, -14672093, ..., -14672093, -14672093,
#         -14672093],
#        [-14672093, -13711113, -13711113, ..., -13711113, -13711113,
#         -14672093],
#        [-14672093, -13711113, -13711113, ..., -13711113, -13711113,
#         -14672093],
#        ...,
#        [-13711113, -13711113, -13711113, ..., -13711113, -13711113,
#         -13711113],
#        [-13711113, -13711113, -13711113, ..., -13711113, -13711113,
#         -13711113],
#        [-13711113, -13711113, -13711113, ..., -14672093, -14672093,
#         -14672093]], dtype=int32)

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=transformed_wine_mask,
               stopwords=stopwords, contour_width=3, contour_color='firebrick')

# Generate a wordcloud
wc.generate(df2)

# store to file
#wc.to_file("img/wine.png")

# show
plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
